# %% [markdown]
# <a href="https://colab.research.google.com/github/sayam2001/Crypto/blob/main/Crypto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('/bitcoin.csv')
df['date'] = df['date'].str[0:11]
df
# Out:
#              date         price  total_volume    market_cap coin_name
# 0     2015-01-01     313.992000  4.699936e+07  4.293958e+09   bitcoin
# 1     2015-01-02     314.446000  3.885591e+07  4.301448e+09   bitcoin
# 2     2015-01-03     286.572000  1.187789e+08  3.921358e+09   bitcoin
# 3     2015-01-04     260.936000  2.055001e+08  3.571640e+09   bitcoin
# 4     2015-01-05     273.220000  1.550381e+08  3.740880e+09   bitcoin
# ...           ...           ...           ...           ...       ...
# 3314  2024-01-29   42026.578562  1.366991e+10  8.242401e+11   bitcoin
# 3315  2024-01-30   43267.609276  2.068032e+10  8.491990e+11   bitcoin
# 3316  2024-01-31   42892.034530  2.452666e+10  8.392941e+11   bitcoin
# 3317  2024-02-01   42583.263547  2.219794e+10  8.354214e+11   bitcoin
# 3318  2024-02-02   43069.043421  2.244368e+10  8.445852e+11   bitcoin
#
# [3319 rows x 5 columns]

# %%
x=df.iloc[:,2:4].values
y=df.iloc[:,-4].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.pipeline import Pipeline

knn_model = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="mean")),
        ("knn", KNeighborsRegressor(n_neighbors=5)),
    ]
)

knn_model.fit(x_train, y_train)

y_pred = knn_model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)


print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 97331.64477361026
# R-squared: 0.9996250727262823

# %%
filename = 'Crypto.joblib'
joblib.dump(knn_model, filename)
# Out:
# ['Crypto.joblib']

# %%
filename = 'Crypto.joblib'
loaded_model = joblib.load(filename)

# %%
df=pd.read_csv('/ethereum.csv')

# %%
x=df.iloc[:,2:4].values
y=df.iloc[:,-4].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

from sklearn.pipeline import Pipeline

knn_model = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="mean")),
        ("knn", KNeighborsRegressor(n_neighbors=5)),
    ]
)

knn_model.fit(x_train, y_train)

y_pred = knn_model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)


print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 416.4471947738485
# R-squared: 0.9996363438648941

# %%
df1 = df[['date', 'price']]

df1['price_lag'] = df1['price'].shift(1)
df1 = df1[1:]


def up_or_down(price_today, price_yest):
    if price_today > price_yest:
        return 1
    else:
        return 0

df1['up_or_down'] = df1[['price', 'price_lag']].apply(lambda x:up_or_down(*x), axis=1)
df1 = df1[['date', 'up_or_down']]

df1
# Out:
# <ipython-input-81-1c76bc3baed6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['price_lag'] = df1['price'].shift(1)
#              date  up_or_down
# 1     2015-08-08            0
# 2     2015-08-10            0
# 3     2015-08-11            1
# 4     2015-08-12            1
# 5     2015-08-13            1
# ...           ...         ...
# 3096  2024-01-29            0
# 3097  2024-01-30            1
# 3098  2024-01-31            1
# 3099  2024-02-01            0
# 3100  2024-02-02            1
#
# [3100 rows x 2 columns]
